# %%
# Dependencies and Setup
#!pip install sqlalchemy psycopg2
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://{username}:{password}@{ipaddress}:{port}/{dbname}')
connection = engine.connect()

# %%
# Import the departments table
departments = pd.read_sql('select * from departments', connection)
departments
# Out:
#   dept_no           dept_name
# 0    d001           Marketing
# 1    d002             Finance
# 2    d003     Human Resources
# 3    d004          Production
# 4    d005         Development
# 5    d006  Quality Management
# 6    d007               Sales
# 7    d008            Research
# 8    d009    Customer Service

# %%
# Import the dept_emp table
dept_emp = pd.read_sql('select * from dept_emp', connection)
dept_emp
# Out:
#         emp_no dept_no
# 0        10001    d005
# 1        10002    d007
# 2        10003    d004
# 3        10004    d004
# 4        10005    d003
# ...        ...     ...
# 331598  499995    d004
# 331599  499996    d004
# 331600  499997    d005
# 331601  499998    d002
# 331602  499999    d004
#
# [331603 rows x 2 columns]

# %%
# Import the dept_manager table
dept_manager = pd.read_sql('select * from dept_manager', connection)
dept_manager
# Out:
#    dept_no  emp_no
# 0     d001  110022
# 1     d001  110039
# 2     d002  110085
# 3     d002  110114
# 4     d003  110183
# 5     d003  110228
# 6     d004  110303
# 7     d004  110344
# 8     d004  110386
# 9     d004  110420
# 10    d005  110511
# 11    d005  110567
# 12    d006  110725
# 13    d006  110765
# 14    d006  110800
# 15    d006  110854
# 16    d007  111035
# 17    d007  111133
# 18    d008  111400
# 19    d008  111534
# 20    d009  111692
# 21    d009  111784
# 22    d009  111877
# 23    d009  111939

# %%
# Import the employees table
employees = pd.read_sql('select * from employees', connection)
employees
# Out:
#         emp_no emp_title_id  birth_date   first_name  last_name sex  \
# 0       473302        s0001  1953-07-25     Hideyuki   Zallocco  M
# 1       475053        e0002  1954-11-18        Byong  Delgrande  F
# 2        57444        e0002  1958-01-30        Berry       Babb  F
# 3       421786        s0001  1957-09-28        Xiong   Verhoeff  M
# 4       282238        e0003  1952-10-28   Abdelkader    Baumann  F
# ...        ...          ...         ...          ...        ...  ..
# 300019  464231        s0001  1958-08-14  Constantino    Eastman  M
# 300020  255832        e0002  1955-05-08       Yuping     Dayang  F
# 300021   76671        s0001  1959-06-09       Ortrud   Plessier  M
# 300022  264920        s0001  1959-09-22        Percy   Samarati  F
# 300023  464503        s0002  1964-05-31       Arvind  Slobodova  M
#
#          hire_date
# 0       1990-04-28
# 1       1991-09-07
# 2       1992-03-21
# 3       1987-11-26
# 4       1991-01-18
# ...            ...
# ...

# %%
# Import the salaries table
salaries = pd.read_sql('select * from salaries', connection)
salaries
# Out:
#         emp_no  salary
# 0        10001   60117
# 1        10002   65828
# 2        10003   40006
# 3        10004   40054
# 4        10005   78228
# ...        ...     ...
# 300019  499995   40000
# 300020  499996   58058
# 300021  499997   49597
# 300022  499998   40000
# 300023  499999   63707
#
# [300024 rows x 2 columns]

# %%
# Import the titles table
titles = pd.read_sql('select * from titles', connection)
titles
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer
# 5    e0004    Technique Leader
# 6    m0001             Manager

# %%
# Merge the employees table and salaries table into a single dataset
employees_salaries = pd.merge(employees, salaries, how='left', on='emp_no')
employees_salaries = employees_salaries.rename(columns={"emp_title_id":"title_id"})
employees_salaries
# Out:
#         emp_no title_id  birth_date   first_name  last_name sex   hire_date  \
# 0       473302    s0001  1953-07-25     Hideyuki   Zallocco  M   1990-04-28
# 1       475053    e0002  1954-11-18        Byong  Delgrande  F   1991-09-07
# 2        57444    e0002  1958-01-30        Berry       Babb  F   1992-03-21
# 3       421786    s0001  1957-09-28        Xiong   Verhoeff  M   1987-11-26
# 4       282238    e0003  1952-10-28   Abdelkader    Baumann  F   1991-01-18
# ...        ...      ...         ...          ...        ...  ..         ...
# 300019  464231    s0001  1958-08-14  Constantino    Eastman  M   1988-10-28
# 300020  255832    e0002  1955-05-08       Yuping     Dayang  F   1995-02-26
# 300021   76671    s0001  1959-06-09       Ortrud   Plessier  M   1988-02-24
# 300022  264920    s0001  1959-09-22        Percy   Samarati  F   1994-09-08
# 300023  464503    s0002  1964-05-31       Arvind  Slobodova  M   1987-11-23
#
#         salary
# 0        40000
# 1        53422
# ...

# %%
# Merge the employees table, salaries table and title table into a single dataset
title_salaries = pd.merge(employees_salaries, titles, how='inner', on='title_id')
title_salaries
# Out:
#         emp_no title_id  birth_date  first_name   last_name sex   hire_date  \
# 0       473302    s0001  1953-07-25    Hideyuki    Zallocco  M   1990-04-28
# 1       421786    s0001  1957-09-28       Xiong    Verhoeff  M   1987-11-26
# 2       273487    s0001  1957-04-14   Christoph     Parfitt  M   1991-06-28
# 3       246449    s0001  1958-03-23       Subbu  Bultermann  F   1988-03-25
# 4        48085    s0001  1964-01-19  Venkatesan        Gilg  M   1993-06-28
# ...        ...      ...         ...         ...         ...  ..         ...
# 300019  111400    m0001  1959-11-09        Arie     Staelin  M   1985-01-01
# 300020  111133    m0001  1955-03-16       Hauke       Zhang  M   1986-12-30
# 300021  110085    m0001  1959-10-28        Ebru       Alpin  M   1985-01-01
# 300022  110386    m0001  1953-10-04        Shem      Kieras  M   1988-10-14
# 300023  111784    m0001  1956-06-14       Marjo  Giarratana  F   1988-02-12
#
#         salary    title
# 0        40000    Staff
# ...
